# %% [markdown]
# <a href="https://colab.research.google.com/github/FadQode/skripsi-modelling/blob/main/dataset-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Data Loading & Understanding ########
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

import re

# %% [markdown]
# # Data Loading and Preparation

# %% [markdown]
# ## Data Loading

# %%
DATASET_PATH_1 = '../../dataset/data2_fad.xlsx'
DATASET_PATH_2 = '../../dataset/data2_shafa.xlsx'
DATASET_PATH_3 = '../../dataset/data_subcpmk_fadhil.xlsx'
DATASET_PATH_4 = '../../dataset/data_subcpmk_shafa.xlsx'

# %%
df_1 = pd.read_excel(DATASET_PATH_1, skiprows=1)
df_2 = pd.read_excel(DATASET_PATH_2, skiprows=1)
df_3 = pd.read_excel(DATASET_PATH_3)
df_4 = pd.read_excel(DATASET_PATH_4)

df = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)

df.drop(columns=["Unnamed: 5", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8", "Unnamed: 9", "Unnamed: 10"], inplace=True)

df.head()
# Out:
#    nomor level_cpmk                                               cpmk  \
# 0      5         C6  Mampu merencanakan, menyelesaikan, dan mengeva...
# 1      6         C6  Mampu merencanakan, menyelesaikan, dan mengeva...
# 2      7         C6  Mampu merencanakan, menyelesaikan, dan mengeva...
# 3     40         C6                        Mampu merancang gardu induk
# 4     41         C6                        Mampu merancang gardu induk
#
#   level_subcpmk                                            subcpmk
# 0            C6  Merencanakan aplikasi menggunakan prinsip dasa...
# 1            C2            Menyelesaikan logic functions and gates
# 2            C5  Mengevaluasi boolean algebra dan combinational...
# 3            C6      Mampu merancang instalasi listrik gardu induk
# 4            C6    Mampu merancang sistem pengetanahan gardu induk

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df[["cpmk", "subcpmk"]] = df[["cpmk", "subcpmk"]].applymap(lambda x: clean_text(x) if isinstance(x, str) else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nomor          1288 non-null   int64
#  1   level_cpmk     1288 non-null   object
#  2   cpmk           1288 non-null   object
#  3   level_subcpmk  1288 non-null   object
#  4   subcpmk        1288 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 50.4+ KB

# %% [markdown]
# ## Cleaning Dataset

# %%
df[df.isna().any(axis=1)]

df.dropna(inplace=True)

# %%
df[["cpmk", "level_cpmk", "subcpmk","level_subcpmk"]] = df[["cpmk", "level_cpmk", "subcpmk","level_subcpmk"]].apply(lambda x: x.astype(str).str.replace('`','', regex=False).str.strip())
df[["cpmk", "level_cpmk", "subcpmk","level_subcpmk"]] = df[["cpmk", "level_cpmk", "subcpmk","level_subcpmk"]].apply(lambda x: x.str.strip())
df[["cpmk", "level_cpmk", "subcpmk","level_subcpmk"]].head()
# Out:
#                                                 cpmk level_cpmk  \
# 0  mampu merencanakan menyelesaikan dan mengevalu...         C6
# 1  mampu merencanakan menyelesaikan dan mengevalu...         C6
# 2  mampu merencanakan menyelesaikan dan mengevalu...         C6
# 3                        mampu merancang gardu induk         C6
# 4                        mampu merancang gardu induk         C6
#
#                                              subcpmk level_subcpmk
# 0  merencanakan aplikasi menggunakan prinsip dasa...            C6
# 1            menyelesaikan logic functions and gates            C2
# 2  mengevaluasi boolean algebra dan combinational...            C5
# 3      mampu merancang instalasi listrik gardu induk            C6
# 4    mampu merancang sistem pengetanahan gardu induk            C6

# %%
df["cpmk"].nunique(), df["subcpmk"].nunique()
# Out:
# (654, 1267)

# %%
df["level_cpmk"].str[0]
# Out:
# 0       C
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1283    P
# 1284    C
# 1285    C
# 1286    A
# 1287    A
# Name: level_cpmk, Length: 1288, dtype: object

# %%
df.loc[df["level_cpmk"].str[0] == 'C']
# Out:
#       nomor level_cpmk                                               cpmk  \
# 0         5         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 1         6         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 2         7         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 3        40         C6                        mampu merancang gardu induk
# 4        41         C6                        mampu merancang gardu induk
# ...     ...        ...                                                ...
# 1265   5971         C3  mampu melakukan pencarian data di database sec...
# 1274   6076         C2  mahasiswa mampu memahami konsep dasar komputer...
# 1280    646         C4  mampu menganalisis masalah kontekstual pkn men...
# 1284   2063         C4  mampu menganalisis masalah kontekstual pkn men...
# 1285   2655         C3  mahasiswa mampu menafsirkan dan menerapkan nil...
#
#      level_subcpmk                                            subcpmk
# 0               C6  merencanakan aplikasi menggunakan prinsip dasa...
# 1               C2            menyelesaikan logic functions and gates
# 2               C5  mengevaluasi boolean algebra dan combinational...
# 3               C6      mampu merancang instalasi listrik gardu induk
# 4               C6    mampu merancang sistem pengetanahan gardu induk
# ...            ...                                                ...
# 1265            C3  mampu melakukan pencarian data di database online
# 1274            C2  mahasiswa mampu mendeskripsikan konsep dasar k...
# 1280            A5  mampu menunjukan pelaksanaan pendidikan anti k...
# 1284            A5  mampu menunjukan pelaksanaan penegakan hukum h...
# 1285            A5  mahasiswa mampu menunjukkan implementasi nilai...
#
# [994 rows x 5 columns]

# %% [markdown]
# ## Alignment Labeling

# %%
def alignment_check(row):
    cpmk_domain = row["level_cpmk"][0]
    cpmk_level  = int(row["level_cpmk"][1])

    sub_domain = row["level_subcpmk"][0]
    sub_level  = int(row["level_subcpmk"][1])

    if cpmk_domain != sub_domain:
        return False

    if cpmk_level < sub_level:
        return False

    return True

df["keselarasan"] = df.apply(alignment_check, axis=1)

df.head()
# Out:
#    nomor level_cpmk                                               cpmk  \
# 0      5         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 1      6         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 2      7         C6  mampu merencanakan menyelesaikan dan mengevalu...
# 3     40         C6                        mampu merancang gardu induk
# 4     41         C6                        mampu merancang gardu induk
#
#   level_subcpmk                                            subcpmk  \
# 0            C6  merencanakan aplikasi menggunakan prinsip dasa...
# 1            C2            menyelesaikan logic functions and gates
# 2            C5  mengevaluasi boolean algebra dan combinational...
# 3            C6      mampu merancang instalasi listrik gardu induk
# 4            C6    mampu merancang sistem pengetanahan gardu induk
#
#    keselarasan
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True

# %%
df["keselarasan"].value_counts()
# Out:
# keselarasan
# True     878
# False    410
# Name: count, dtype: int64

# %%
vc_sub = df["level_subcpmk"].value_counts()
vc_cpmk = df["level_cpmk"].value_counts()

hasil = vc_sub.add(vc_cpmk, fill_value=0)
hasil
# Out:
# A2      3.0
# A3      5.0
# A4     78.0
# A5     77.0
# C1     87.0
# C2    491.0
# C3    292.0
# C4    488.0
# C5    211.0
# C6    466.0
# P2     29.0
# P3    224.0
# P4    103.0
# P5     22.0
# Name: count, dtype: float64

# %% [markdown]
# ## Modelling Dataset 1 - Learning Outcome Text & Bloom Label

# %%
# Pecah CPMK menjadi data terpisah
df_cpmk = df[['cpmk']].copy()
df_cpmk['Jenis'] = 'CPMK'
df_cpmk['Level'] = df['level_cpmk']

df_cpmk.rename(columns={'cpmk':'Learning_Outcome'}, inplace=True)

# Pecah Sub-CPMK
df_sub = df[['subcpmk']].copy()
df_sub['Jenis'] = 'Sub-CPMK'
df_sub['Level'] = df['level_subcpmk']

df_sub.rename(columns={'subcpmk':'Learning_Outcome',
                       'level_subcpmk':'level_cpmk'}, inplace=True)

# Gabungkan
df_learning_outcome = pd.concat([df_cpmk, df_sub], ignore_index=True)
df_learning_outcome
# Out:
#                                        Learning_Outcome     Jenis Level
# 0     mampu merencanakan menyelesaikan dan mengevalu...      CPMK    C6
# 1     mampu merencanakan menyelesaikan dan mengevalu...      CPMK    C6
# 2     mampu merencanakan menyelesaikan dan mengevalu...      CPMK    C6
# 3                           mampu merancang gardu induk      CPMK    C6
# 4                           mampu merancang gardu induk      CPMK    C6
# ...                                                 ...       ...   ...
# 2571  mahasiswa dapat memahami dan mempraktekkan iba...  Sub-CPMK    P3
# 2572  mampu menunjukan pelaksanaan penegakan hukum h...  Sub-CPMK    A5
# 2573  mahasiswa mampu menunjukkan implementasi nilai...  Sub-CPMK    A5
# 2574  mampu bertindak mengimplementasikan makna sila...  Sub-CPMK    A5
# 2575  mampu bertindak mengimplementasikan sila ke da...  Sub-CPMK    A5
#
# [2576 rows x 3 columns]

# %%
df_learning_outcome.to_csv('../../dataset/learning_outcomes.csv', index=False)

# %%
df_learning_outcome['Learning_Outcome'].nunique()
# Out:
# 1895

# %%
df_learning_outcome["Level"].str[0]
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'C'].value_counts().sum())
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'P'].value_counts().sum())
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'A'].value_counts().sum())
# Out:
# 2035
# 378
# 163

# %%
counts = (
    df_learning_outcome["Level"]
    .str[0]                      # ambil huruf depan: C / P / A
    .value_counts()
    .reindex(["C", "P", "A"], fill_value=0)
    .reset_index()
)

counts.columns = ["Domain", "Jumlah"]

fig = px.pie(
    counts,
    names="Domain",
    values="Jumlah",
    title="Proporsi Domain Taksonomi Bloom pada Learning Outcome",
    hole=0.4
)

fig.update_traces(textinfo="value+label")
fig.show()

# %%
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'C'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'P'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == 'A'].nunique())
# Out:
# Learning_Outcome    1523
# Jenis                  2
# Level                  6
# dtype: int64
# Learning_Outcome    280
# Jenis                 2
# Level                 4
# dtype: int64
# Learning_Outcome    103
# Jenis                 2
# Level                 4
# dtype: int64

# %%
import plotly.express as px
import pandas as pd

# Hitung nunique per domain
data = {
    "Domain": ["Kognitif", "Psikomotor", "Afektif"],
    "Jumlah Unik": [
        df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == "C"].nunique().max(),
        df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == "P"].nunique().max(),
        df_learning_outcome.loc[df_learning_outcome["Level"].str[0] == "A"].nunique().max(),
    ]
}

df_unique = pd.DataFrame(data)

fig = px.pie(
    df_unique,
    names="Domain",
    values="Jumlah Unik",
    title="Jumlah Nilai Unik Learning Outcome Berdasarkan Domain Taksonomi Bloom",
    hole=0.4
)

fig.update_traces(textposition="outside", textinfo="value+label")


fig.show()

# %%
df_sample = (
    df_learning_outcome
    .assign(Domain=df_learning_outcome["Level"].str[0])
    .groupby("Domain", group_keys=False)
    .apply(lambda x: x.sample(n=min(2, len(x)), random_state=42))
)

df_sample
# Out:
#                                        Learning_Outcome     Jenis Level Domain
# 2111  menggali potensi diri untuk berwirausaha dan m...  Sub-CPMK    A5      A
# 1608  mengintegrasikan nilai nilai etika komunikasi ...  Sub-CPMK    A4      A
# 729   mahasiswa mampu mengevaluasi transfer aset tid...      CPMK    C5      C
# 117   mahasiswa mampu menelaah kompetensi dan tupoks...      CPMK    C4      C
# 2148  mahasiswa mampu membuka dan menutup pelajaran ...  Sub-CPMK    P3      P
# 2376  mampu mempraktekkan prinsip makanan oral bentu...  Sub-CPMK    P3      P

# %%
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'A1'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'A2'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'A3'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'A4'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'A5'].nunique())
# Out:
# Learning_Outcome    0
# Jenis               0
# Level               0
# dtype: int64
# Learning_Outcome    3
# Jenis               1
# Level               1
# dtype: int64
# Learning_Outcome    5
# Jenis               1
# Level               1
# dtype: int64
# Learning_Outcome    55
# Jenis                2
# Level                1
# dtype: int64
# Learning_Outcome    42
# Jenis                2
# Level                1
# dtype: int64

# %%
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'P1'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'P2'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'P3'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'P4'].nunique())
print(df_learning_outcome.loc[df_learning_outcome["Level"] == 'P5'].nunique())
# Out:
# Learning_Outcome    0
# Jenis               0
# Level               0
# dtype: int64
# Learning_Outcome    20
# Jenis                2
# Level                1
# dtype: int64
# Learning_Outcome    169
# Jenis                 2
# Level                 1
# dtype: int64
# Learning_Outcome    74
# Jenis                2
# Level                1
# dtype: int64
# Learning_Outcome    17
# Jenis                2
# Level                1
# dtype: int64

# %%
df_learning_outcome["Level"].value_counts()

fig = px.bar(
    df_learning_outcome["Level"].value_counts().reset_index().rename(columns={
        "count": "Jumlah",
        "Level": "Level"
    }),
    x="Jumlah",
    y="Level",
    title="Distribusi Learning Outcome berdasarkan Level Taksonomi Bloom",
    text="Jumlah"
)

fig.update_traces(textposition="outside",  texttemplate="%{x}")
fig.show()

# %% [markdown]
# ## Modelling Dataset 2 - Learning - Sub-Learning  & Alignment Label

# %%
df_pair =   df[['cpmk', 'level_cpmk', 'subcpmk', 'level_subcpmk', 'keselarasan']].copy()

df_pair = df_pair.applymap(lambda x: clean_text(x) if isinstance(x, str) else x)
df_pair
# Out:
#                                                    cpmk level_cpmk  \
# 0     mampu merencanakan menyelesaikan dan mengevalu...          c
# 1     mampu merencanakan menyelesaikan dan mengevalu...          c
# 2     mampu merencanakan menyelesaikan dan mengevalu...          c
# 3                           mampu merancang gardu induk          c
# 4                           mampu merancang gardu induk          c
# ...                                                 ...        ...
# 1283  mahasiswa mampu mempraktekkan haji umroh dan q...          p
# 1284  mampu menganalisis masalah kontekstual pkn men...          c
# 1285  mahasiswa mampu menafsirkan dan menerapkan nil...          c
# 1286  mampu menunjukan nilai ketuhanan nilai kemanus...          a
# 1287  mampu menunjukan nilai ketuhanan nilai kemanus...          a
#
#                                                 subcpmk level_subcpmk  \
# 0     merencanakan aplikasi menggunakan prinsip dasa...             c
# 1               menyelesaikan logic functions and gates             c
# 2     mengevaluasi boolean algebra dan combinational...             c
# 3         mampu merancang instalasi listrik gardu induk             c
# 4       mampu merancang sistem pengetanahan gardu induk             c
# ...                                                 ...           ...
# 1283  mahasiswa dapat memahami dan mempraktekkan iba...             p
# 1284  mampu menunjukan pelaksanaan penegakan hukum h...             a
# 1285  mahasiswa mampu menunjukkan implementasi nilai...             a
# 1286  mampu bertindak mengimplementasikan makna sila...             a
# 1287  mampu bertindak mengimplementasikan sila ke da...             a
#
#       keselarasan
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ...           ...
# 1283         True
# 1284        False
# 1285        False
# 1286         True
# 1287         True
#
# [1288 rows x 5 columns]

# %%
df_pair.to_csv('../../dataset/cpmk_subcpmk_pairs.csv', index=False)

# %%
df_pair["keselarasan"] = df_pair["keselarasan"].map({
    True: "Selaras",
    False: "Tidak Selaras"
})

df_pair_sample = (
    df_pair
    .apply(lambda x: x.sample(n=min(4, len(x)), random_state=42))
)

df_pair_sample
# Out:
#                                                    cpmk level_cpmk  \
# 1120  mahasiswa mampu mempraktikan dan analisis terh...          c
# 1185  mahasiswa mampu mempraktikkan proses rekrutmen...          p
# 462   mampu menyajikan serta mengolah data secara il...          c
# 81    mahasiswa mampu melakukan analisis gender dan ...          c
#
#                                                 subcpmk level_subcpmk  \
# 1120  mahasiswa mampu mengidentifikasi profil tanah ...             c
# 1185  mahasiswa melakukan evaluasi terhadap proses s...             c
# 462                   mampu mengolah data secara ilmiah             c
# 81    mahasiswa mampu menjelaskan langkah analisis p...             c
#
#         keselarasan
# 1120        Selaras
# 1185  Tidak Selaras
# 462         Selaras
# 81          Selaras
